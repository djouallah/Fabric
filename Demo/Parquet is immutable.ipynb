# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

df = spark.sql("SELECT * FROM Delta_Table.region LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, a7a7eb0d-53d2-453f-8c3b-c34890129757)

# %%
spark.sql("delete FROM Delta_Table.region where r_name ='ASIA' ")
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 4, Finished, Available)
# DataFrame[num_affected_rows: bigint]

# %%
df = spark.sql("SELECT * FROM Delta_Table.region LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, e5dc6295-3440-4206-a151-e6cad0e0d124)

# %%
spark.sql("insert into Delta_Table.region values (5,'ASIA','random comment') ")
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 6, Finished, Available)
# DataFrame[]

# %%
df = spark.sql("SELECT * FROM Delta_Table.region LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 7, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 67bedec4-8850-4835-b773-4b02d8cd46c5)

# %%
df = spark.sql("update Delta_Table.region set r_comment ='new comment' where r_regionkey = 5 ")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 8, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 245fe002-214c-4b2e-8201-2b23ccd1fbec)

# %%
df = spark.sql("SELECT * FROM Delta_Table.region LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 9, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 4bb61341-e3c1-4ea8-bb9d-97c31a17539c)

# %%
df = spark.sql("update Delta_Table.region set r_comment ='Hi Mum' where r_regionkey = 0 ")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 18, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 8d20aeb9-0a32-4e58-a811-387f5ed36ef2)

# %%
df = spark.sql("SELECT * FROM Delta_Table.region LIMIT 1000")
display(df)
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 11, Finished, Available)
# SynapseWidget(Synapse.DataFrame, acddbb62-09f8-4000-8806-8af2683b16bc)

# %%
spark.sql("vacuum Delta_Table.region RETAIN 1 HOURS ").show()
# Out:
# StatementMeta(, 84e507f9-781f-48c6-ba1e-9988975aceff, 3, Finished, Available)
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spark.sql("vacuum Delta_Table.region RETAIN 1 HOURS ").show()
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:1034, in SparkSession.sql(self, sqlQuery, **kwargs)
#    1032     sqlQuery = formatter.format(sqlQuery, **kwargs)
#    1033 try:
# -> 1034     return DataFrame(self._jsparkSession.sql(sqlQuery), self)
#    1035 finally:
#    1036     if len(kwargs) > 0:
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# ...

# %%
spark.sql("DESCRIBE HISTORY Delta_Table.region ").show()
# Out:
# StatementMeta(, a2cee5c1-d805-4b4e-9e27-a3da1af182a2, 21, Finished, Available)
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+--------------+-------------+--------------------+------------+--------------------+
# |version|           timestamp|userId|userName|operation| operationParameters| job|notebook|clusterId|readVersion|isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+--------------------+------+--------+---------+--------------------+----+--------+---------+-----------+--------------+-------------+--------------------+------------+--------------------+
# |     11|2023-06-21 04:47:...|  null|    null|   UPDATE|{predicate -> (r_...|null|    null|     null|         10|  Serializable|        false|{numRemovedFiles ...|        null|Apache-Spark/3.3....|
# ...
